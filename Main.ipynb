# %%
import pandas as pd
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager # sustituye al archivo
PATH = ChromeDriverManager().install()     # instala el driver de chrome

driver=webdriver.Chrome(PATH)       # abre una venta una de chrome
from selenium.webdriver.common.by import By # By es para buscar por tag, clase, id...

import time

import warnings
warnings.filterwarnings('ignore')

# %%
import regex as re
import src
import requests as req
from bs4 import BeautifulSoup as bs

# %%
#driver configuration
opciones=Options()

opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)
opciones.headless=False    # si True, no aperece la ventana (headless=no visible)
opciones.add_argument('--start-maximized')         # comienza maximizado
#opciones.add_argument('user-data-dir=selenium')    # mantiene las cookies
#opciones.add_extension('driver_folder/adblock.crx')       # adblocker
opciones.add_argument('--incognito')

# %%
def don_limpio(urls):
    resultados = []
    for url in urls:
        response = req.get(url)
        soup = bs(response.text, 'html.parser')
        lista = [i.text for i in soup.find_all("p")]

        indice = None
        for i, char in enumerate(lista):
            if char == "———":
                indice = i

        texto_final = lista[2:indice]
        cuerpo = []
        for str in texto_final:
            cuerpo.append(re.sub(r'[\[\]\{\}]', '', str))

        obra = lista[1]
        resultados.append((cuerpo, obra))

    return resultados

# %% [markdown]
# ### Vamos a conseguir las URLs de la Moral a Nicómaco

# %%
driver = r"C:\Users\Juan\.wdm\drivers\chromedriver\win32\113.0.5672.63\chromedriver.exe" 
driver = webdriver.Chrome(driver,options = opciones)
driver.get("https://www.filosofia.org/cla/ari/azc01.htm#pri")  #nos devuelve todos los links de la página que contiene 
                                                               #todas las URLs de todos los libros de la moral a Nicómaco
t = driver.find_elements(By.TAG_NAME, "a")
listam = [i.get_attribute("href") for i in t]
driver.quit()
#url_moral = lista[14:]

# %%
moral_nicomaco = don_limpio(listam[14:127])

# %%
moral_nicomaco
# Out:
# [(['Todas las artes, todas las indagaciones metódicas del espíritu, lo mismo que todos nuestros actos y todas nuestras determinaciones morales, tienen al parecer siempre por mira algún bien que deseamos conseguir; y por esta razón ha sido exactamente definido el bien, cuando se ha dicho, que es el objeto de todas nuestras aspiraciones. ',
# ...

# %%
driver = r"C:\Users\Juan\.wdm\drivers\chromedriver\win32\113.0.5672.63\chromedriver.exe" 
driver = webdriver.Chrome(driver,options = opciones)
driver.get("https://www.filosofia.org/cla/ari/azc02a.htm")  

t = driver.find_elements(By.TAG_NAME, "a")
gran_etica_urls = [i.get_attribute("href") for i in t]

driver.quit()

# %%
'https://www.filosofia.org/cla/ari/azc02007.htm'
'https://www.filosofia.org/cla/ari/azc02105.htm'
print(lista.index('https://www.filosofia.org/cla/ari/azc02007.htm'))
print(lista.index('https://www.filosofia.org/cla/ari/azc02105.htm'))
# Out:
# 5
# 55

# %%
e_m = don_limpio(lista[5:55])

# %% [markdown]
# ### Política

# %%
driver = r"C:\Users\Juan\.wdm\drivers\chromedriver\win32\113.0.5672.63\chromedriver.exe" 
driver = webdriver.Chrome(driver,options = opciones)
driver.get("https://www.filosofia.org/cla/ari/azc03.htm") 

t = driver.find_elements(By.TAG_NAME, "a")
politica_urls = [i.get_attribute("href") for i in t]
driver.quit()

# %%
politica_urls
# Out:
# ['https://www.filosofia.org/ave/001/a239.htm',
#  'https://www.filosofia.org/cla/ari/azc03.htm#pri',
#  'https://www.filosofia.org/cla/ari/azc03.htm#seg',
#  'https://www.filosofia.org/cla/ari/azc03.htm#ter',
#  'https://www.filosofia.org/cla/ari/azc03.htm#cua',
#  'https://www.filosofia.org/cla/ari/azc03.htm#qui',
#  'https://www.filosofia.org/cla/ari/azc03.htm#sex',
#  'https://www.filosofia.org/cla/ari/azc03.htm#sep',
#  'https://www.filosofia.org/cla/ari/azc03.htm#oct',
#  'https://www.filosofia.org/ave/001/a163.htm',
#  'https://www.filosofia.org/cla/ari/azcarate.htm',
#  'https://www.filosofia.org/bol/bib/nb028.htm',
#  'https://www.filosofia.org/cla/ari/azc03007.htm',
#  'https://www.filosofia.org/cla/ari/azc03017.htm',
#  'https://www.filosofia.org/cla/ari/azc03021.htm',
#  'https://www.filosofia.org/cla/ari/azc03028.htm',
#  'https://www.filosofia.org/cla/ari/azc03036.htm',
#  'https://www.filosofia.org/cla/ari/azc03038.htm',
# ...

# %%
'https://www.filosofia.org/cla/ari/azc03017.htm'#libro 1 de la politica
'https://www.filosofia.org/cla/ari/azc03286.htm' #ultimo libro de la politica
print(politica_urls.index('https://www.filosofia.org/cla/ari/azc03017.htm'))
print(politica_urls.index('https://www.filosofia.org/cla/ari/azc03286.htm'))
# Out:
# 13
# 88

# %%
politica = don_limpio(politica_urls[13:88])

# %% [markdown]
# ### Gran Moral

# %%
driver = r"C:\Users\Juan\.wdm\drivers\chromedriver\win32\113.0.5672.63\chromedriver.exe" 
driver = webdriver.Chrome(driver,options = opciones)
driver.get("https://www.filosofia.org/cla/ari/azc02a.htm")  

t = driver.find_elements(By.TAG_NAME, "a")
gran_etica_urls = [i.get_attribute("href") for i in t]

driver.quit()

# %%
print(gran_etica_urls.index("https://www.filosofia.org/cla/ari/azc02007.htm"))
print(gran_etica_urls.index('https://www.filosofia.org/cla/ari/azc02105.htm'))
# Out:
# 5
# 55

# %%
gran_moral = don_limpio(gran_etica_urls[5:55])

# %%
gran_moral
# Out:
# [(['Siendo nuestra intención tratar aquí de cosas pertenecientes a la moral, lo primero que tenemos que hacer es averiguar exactamente de qué ciencia forma parte. La moral, a mi juicio, sólo puede formar parte de la política. En política no es posible practicar cosa alguna sin estar dotado de ciertas cualidades; quiero decir, sin ser hombre de bien. Pero ser hombre de bien equivale a tener virtudes; y por tanto, si en política se quiere hacer algo, es preciso ser moralmente virtuoso. Esto hace que parezca el estudio de la moral como una parte y aun como el principio de la política, y por consiguiente sostengo que al conjunto de este estudio debe dársele el nombre de política más bien que el de moral. Creo por lo tanto que debe tratarse en primer término de la virtud, y hacer ver cómo es y cómo se forma, porque ningún provecho se sacará de saber lo que es la virtud si no se sabe también cómo nace y por qué medios se adquiere. Sería un error estudiar la virtud con el único objeto de 8 
# ...

# %% [markdown]
# ### Metafísica

# %%
res = req.get("https://www.filosofia.org/cla/ari/azc10.htm")
soup = bs(res.text, "html.parser")

links_meta = []

for link in soup.find_all("a"):
    l = link.get("href")
    links_meta.append(l)

print(links_meta)   #no funciona lo que veníamos haciendo con selenium, nos cambiamos a bs en este caso, es esencialmente lo mismo
# Out:
# ['../../ave/001/a239.htm', '#pri', '#seg', '#ter', '#cua', '#qui', '#sex', '#sep', '#oct', '#nov', '#dec', '#und', '#doc', '#tre', '#cat', '../../ave/001/a163.htm', 'azcarate.htm', '../../bol/bib/nb024.htm', 'azc10007.htm', 'azc10051.htm', 'azc10055.htm', 'azc10058.htm', 'azc10063.htm', 'azc10066.htm', 'azc10070.htm', 'azc10074.htm', 'azc10089.htm', 'azc10091.htm', 'azc10093.htm', 'azc10095.htm', 'azc10098.htm', 'azc10104.htm', 'azc10107.htm', 'azc10114.htm', 'azc10116.htm', 'azc10119.htm', 'azc10120.htm', 'azc10125.htm', 'azc10127.htm', 'azc10135.htm', 'azc10142.htm', 'azc10144.htm', 'azc10145.htm', 'azc10149.htm', 'azc10151.htm', 'azc10154.htm', 'azc10155.htm', 'azc10157.htm', 'azc10158.htm', 'azc10162.htm', 'azc10164.htm', 'azc10165.htm', 'azc10166.htm', 'azc10167.htm', 'azc10169.htm', 'azc10172.htm', 'azc10173.htm', 'azc10174.htm', 'azc10176.htm', 'azc10177.htm', 'azc10178.htm', 'azc1017a.htm', 'azc1017b.htm', 'azc1017c.htm', 'azc10180.htm', 'azc10181.htm', 'azc10182.htm', 'azc10
# ...

# %%
#vienen rotos los links por algún motivo, vamos a escoger aquellos que nos interesan y vamos a rellenarlos, por suerte est
#todos rotos de la misma forma
links_meta = links[19:157]
for i, e in enumerate(links_meta):
    links_meta[i] = "https://www.filosofia.org/cla/ari/" + e


print(links_meta)
# Out:
# ['https://www.filosofia.org/cla/ari/https://www.filosofia.org/cla/ari/https://www.filosofia.org/cla/ari/azc10174.htm', 'https://www.filosofia.org/cla/ari/https://www.filosofia.org/cla/ari/https://www.filosofia.org/cla/ari/azc10176.htm', 'https://www.filosofia.org/cla/ari/https://www.filosofia.org/cla/ari/https://www.filosofia.org/cla/ari/azc10177.htm', 'https://www.filosofia.org/cla/ari/https://www.filosofia.org/cla/ari/https://www.filosofia.org/cla/ari/azc10178.htm', 'https://www.filosofia.org/cla/ari/https://www.filosofia.org/cla/ari/https://www.filosofia.org/cla/ari/azc1017a.htm', 'https://www.filosofia.org/cla/ari/https://www.filosofia.org/cla/ari/https://www.filosofia.org/cla/ari/azc1017b.htm', 'https://www.filosofia.org/cla/ari/https://www.filosofia.org/cla/ari/https://www.filosofia.org/cla/ari/azc1017c.htm', 'https://www.filosofia.org/cla/ari/https://www.filosofia.org/cla/ari/https://www.filosofia.org/cla/ari/azc10180.htm', 'https://www.filosofia.org/cla/ari/https://www.filoso
# ...
